# %%
import getpass
conf = sc.getConf().setAppName("the {}\'s spark app".format(getpass.getuser()))
sc.stop()
sc = SparkContext(conf=conf)

from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Spark DF practice').master('yarn').getOrCreate()

# %%
import pandas as pd
from pyspark.sql import *
from pyspark.sql import Window as W
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://mipt-client.atp-fivt.org:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.0.cloudera2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>the hobod2025s008's spark app</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
commits= spark.read.parquet("/data/clickhouse_2022_repodata_parquet_v2/commits").cache()

file_changes= spark.read.parquet("/data/clickhouse_2022_repodata_parquet_v2/file_changes").cache()

line_changes= spark.read.parquet("/data/clickhouse_2022_repodata_parquet_v2/line_changes").cache()

# %%
commits.printSchema()
file_changes.printSchema()
line_changes.printSchema()
# Out:
# root
#  |-- hash: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- time: timestamp (nullable = true)
#  |-- message: string (nullable = true)
#  |-- files_added: integer (nullable = true)
#  |-- files_deleted: integer (nullable = true)
#  |-- files_renamed: integer (nullable = true)
#  |-- files_modified: integer (nullable = true)
#  |-- lines_added: integer (nullable = true)
#  |-- lines_deleted: integer (nullable = true)
#  |-- hunks_added: integer (nullable = true)
#  |-- hunks_removed: integer (nullable = true)
#  |-- hunks_changed: integer (nullable = true)
#
# root
#  |-- change_type: string (nullable = true)
#  |-- path: string (nullable = true)
#  |-- old_path: string (nullable = true)
#  |-- file_extension: string (nullable = true)
#  |-- lines_added: integer (nullable = true)
#  |-- lines_deleted: integer (nullable = true)
#  |-- hunks_added: integer (nullable = true)
#  |-- hunks_removed: integer (nullable = true)
#  |-- hunks_changed: integer (nullable = true)
#  |-- commit_hash: string (nullable = true)
#  |-- commit_files_added: integer (nullable = true)
#  |-- commit_files_deleted: integer (nullable = true)
#  |-- commit_files_renamed: integer (nullable = true)
#  |-- commit_files_modified: integer (nullable = true)
#  |-- commit_lines_added: integer (nullable = true)
#  |-- commit_lines_deleted: integer (nullable = true)
#  |-- commit_hunks_added: integer (nullable = true)
#  |-- commit_hunks_removed: integer (nullable = true)
#  |-- commit_hunks_changed: integer (nullable = true)
#
# root
#  |-- sign: integer (nullable = true)
#  |-- line_number_old: integer (nullable = true)
#  |-- line_number_new: integer (nullable = true)
#  |-- hunk_num: integer (nullable = true)
#  |-- hunk_start_line_number_old: integer (nullable = true)
#  |-- hunk_start_line_number_new: integer (nullable = true)
#  |-- hunk_lines_added: integer (nullable = true)
#  |-- hunk_lines_deleted: integer (nullable = true)
#  |-- hunk_context: string (nullable = true)
#  |-- line: string (nullable = true)
#  |-- indent: integer (nullable = true)
#  |-- line_type: string (nullable = true)
#  |-- prev_commit_hash: string (nullable = true)
#  |-- prev_time: timestamp (nullable = true)
#  |-- file_change_type: string (nullable = true)
#  |-- path: string (nullable = true)
#  |-- old_path: string (nullable = true)
#  |-- file_extension: string (nullable = true)
#  |-- file_lines_added: integer (nullable = true)
#  |-- file_lines_deleted: integer (nullable = true)
#  |-- file_hunks_added: integer (nullable = true)
#  |-- file_hunks_removed: integer (nullable = true)
#  |-- file_hunks_changed: integer (nullable = true)
# 63607  7fc1e45c3b98a4e2dc679d89c9a7d66acc829f91             alesapin
# 63608  fdf4fd337ae0254d682257d559c36665c4ac4e4f   Ildus Kurbangaliev
# 63609  b952487cabbe53610d613eeea1ded1572adae5f2          Anton Popov
# 63610  f4efe3c2fd959f664e3599e00278f4b202ff7cd4       Anton Ivashkin
# 63611  d52f67d24e07751df356606bb6486cebdc91a914             alesapin
# 63612  bf8f28a788f3cc1d2d5f0488e17f46e06fbc9be6     Nikolai Kochetov
# 63613  cbac8bd0835b1fc2d6f5484aa0894b17e6e48e9e             alesapin
# 63614  26ff008898de71d1033d681c861065fae06550e7             alesapin
# 63615  c5d76dac692a6a6f08c8845d2916396369887c9f     alexey-milovidov
# 63616  5c1aa52f406b9647476a7fa06dd1b179cda48793             alesapin
# 63617  d9c78cde6b06b7b30cc0271c6d4b185e56b9757d     Nikolai Kochetov
# 63618  54c6785b360fab770089d94be8edbb04420fb485     Nikolai Kochetov
# 63619  1c5ccd089f33e98488c8eadcce043f90cc0ad036     Nikolai Kochetov
# 63620  fdc49cadb7ae93ed17ac8010dfde07026db82da8     Nikolai Kochetov
# 63621  ba8a29a3a45ab935ded14954cad0a9782329fd36             alesapin
# 63622  9df54946cf4a475b4da40a5a873c9ae525991f4a      nikitamikhaylov
# 63623  133422d5e7885ce64ae1ff4f41971944343a1d0a     Nikolai Kochetov
# 63624  be24184deb2d6e36251a62604556cf6d53095b80     Nikolai Kochetov
# 63625  59d543ca1cd4ea5b8a8ba59186aed773ae7ecf70     Nikolai Kochetov
# 63626  86c1cc71eab871c24305eef9e8d2460ae1f7d7d9      nikitamikhaylov
# 63627  2909d965db109ef0bdcf8561fb377fa3cf206899      nikitamikhaylov
# 63628  d3bcf89ae427dcb2b9cd7def3ac7296de3def723     Nikolai Kochetov
# 63629  2b962e699b2e171884694f4c4ddade014c662362      Pavel Kovalenko
# 63630  c1cbfad59900549042183728397dc81611ec7006             alesapin
# 63631  6bbb0e8c259bdf04641dc6d0d9c3409234309e0d             alesapin
#
#                      time                                            message  \
# 0     2020-07-29 17:09:38            fix wrong index analysis with functions
# 1     2020-07-29 17:09:43               Updated formating of insert.py tests
# 2     2020-07-29 17:20:17  fix access to redis dictionary after connectio...
# 3     2020-07-29 18:05:38                   Fix the AST fuzzer error message
# 4     2020-07-29 18:16:06                      Updated to include ipv6 hosts
# 5     2020-07-29 18:37:57       rewrite other test + remove useless includes
# 6     2020-07-29 19:00:46  Avoid re-loading completion from the history f...
# 7     2020-07-29 19:00:46  Add a comment of explicit flock() in ReplxxLin...
# 8     2020-07-29 19:14:48          remove includes from all Function sources
# 9     2020-07-29 19:15:20             Cache mark and index files for DiskS3.
# 10    2020-07-29 19:20:23  Revert xfail of "connection protocols/tls mini...
# 11    2020-07-29 20:24:58  Fix (generalize) health-check command for open...
# 12    2020-07-29 20:54:00             Change comment in DiskCacheWrapper.cpp
# 13    2020-07-30 02:19:32  Returned `max_data_part_size` to `system.stora...
# 14    2020-07-30 03:43:22              Added another test case for perf test
# 15    2020-07-30 03:47:05              Keep less amount of logs in ZooKeeper
# 16    2020-07-30 10:28:52  Add test for macros usage in certain kafka set...
# 17    2020-07-30 11:04:49                 Tiny fixes and avoid dynamic casts
# 18    2020-07-30 11:31:14                                    another removes
# 19    2020-07-30 12:08:56                             Fix get disk interface
# 20    2020-07-30 12:59:21                                                fix
# 21    2020-07-30 13:09:07  Updating expected error messages to fix failin...
# 22    2020-07-30 14:35:24                               Update run-fuzzer.sh
# 23    2020-07-30 14:37:32        Fixing 00960_live_view_watch_events_live.py
# 24    2020-07-30 14:42:05                       DiskS3 caching improvements.
# 25    2020-07-30 14:43:22                                           pipefail
# 26    2020-07-30 15:26:47                                  Update compare.sh
# 27    2020-07-30 15:27:11                                    Fix error codes
# 28    2020-07-30 15:49:56                           DiskS3 with cache tests.
# 29    2020-07-30 16:20:47   [draft] only fix int16->int32 insert in PODArray
# ...                   ...                                                ...
# 63602 2020-07-29 02:50:12  Slightly improve inner loop of aggregation by ...
# 63603 2020-07-29 06:57:46                 Add integration dictionaries tests
# 63604 2020-07-29 07:03:57  Add X-ClickHouse-Database and X-ClickHouse-Format
# 63605 2020-07-29 08:26:08                            Minor perf. improvement
# 63606 2020-07-29 09:01:16                      adding tests for GRANT SELECT
# 63607 2020-07-29 09:32:52                                        Review fixe
# 63608 2020-07-29 09:50:30      add mapAdd and mapSubtract functions (#11735)
# 63609 2020-07-29 11:22:10                                        remote test
# 63610 2020-07-29 11:32:18  Add QueryTimeMicroseconds, SelectQueryTimeMicr...
# 63611 2020-07-29 12:00:04                                Fix abtesting build
# 63612 2020-07-29 12:06:00                                     Try fix tests.
# 63613 2020-07-29 12:33:38                                    Fix cmake lists
# 63614 2020-07-29 12:34:42                                        Remove test
# 63615 2020-07-29 12:38:57                        Update PipelineExecutor.cpp
# 63616 2020-07-29 12:39:08                      Better check for failed tests
# 63617 2020-07-29 13:19:50                                     Try fix tests.
# 63618 2020-07-29 13:29:20                                     Try fix tests.
# 63619 2020-07-29 13:32:59                                    Added perftest.
# 63620 2020-07-29 13:51:59  Ignore constants for remote query from local r...
# 63621 2020-07-29 14:12:55                    Better logging on mutation skip
# 63622 2020-07-29 15:06:33                               fix clang-tidy build
# 63623 2020-07-29 15:14:13  Ignore constants for remote query from local r...
# 63624 2020-07-29 15:27:37  Ignore constants for remote query from local r...
# 63625 2020-07-29 15:30:03  Ignore constants for remote query from local r...
# 63626 2020-07-29 15:45:16                                                try
# 63627 2020-07-29 15:47:42                                        delete file
# 63628 2020-07-29 15:50:10                                        Added test.
# 63629 2020-07-29 16:05:02             Cache mark and index files for DiskS3.
# 63630 2020-07-29 16:11:02                                   Break some tests
# 63631 2020-07-29 16:53:10                                     Fix some tests
#
#        files_added  files_deleted  files_renamed  files_modified  lines_added  \
# 0                2              0              0               1           78
# 1                0              0              0               2           65
# 2                0              0              0               1            6
# 3                0              0              0               1           15
# 4                0              0              0               1            1
# 5                1              1              0              27          215
# 6                0              0              0               1           14
# 7                0              0              0               1            4
# 8                0              0              0              66            1
# 9                0              0              0               5           92
# 10               0              0              0               5            8
# 11               0              0              0               2            4
# 12               0              0              0               1            1
# 13               0              0              0               2           27
# 14               0              0              0               1            4
# 15               0              0              0               1            2
# 16               1              0              0               1           29
# 17               0              0              0               8           32
# 18               0              0              0              42            0
# 19               0              0              0               2            3
# 20               0              0              0               1            2
# 21               0              0              0               1            5
# 22               0              0              0               1            1
# 23               0              0              0               1            1
# 24               0              0              0               6          111
# 25               0              0              0               1            3
# 26               0              0              0               1            1
# 27               0              0              0               1            2
# 28               5              0              0               2          191
# 29               0              0              0               1            2
# ...            ...            ...            ...             ...          ...
# 63602            0              0              0               2           51
# 63603            1              0              0               1           55
# 63604            2              0              0               2           38
# 63605            0              0              0               1            7
# 63606            1              1              0               1          583
# 63607            0              0              0               5           15
# 63608            4              0              0               2          430
# 63609            0              1              0               0            0
# 63610            2              0              0               2           91
# 63611            1              0              0               6           46
# 63612            0              0              0               6           63
# 63613            0              0              0               1            1
# 63614            0              0              0               1            1
# 63615            0              0              0               1            8
# 63616            0              0              0               1           15
# 63617            0              0              0               1            5
# 63618            0              0              0               2           11
# 63619            1              0              0               0            4
# 63620            0              0              0               2           14
# 63621            0              0              0               1            8
# 63622            0              0              0               1            1
# 63623            0              0              0               1            1
# 63624            0              0              0               3            7
# 63625            0              0              0               1            1
# 63626            1              0              0               1          122
# 63627            0              1              0               0            0
# 63628            2              0              0               0            8
# 63629            4              0              0               1          553
# 63630            0              0              0               2            2
# 63631            0              0              0               2            1
#
#        lines_deleted  hunks_added  hunks_removed  hunks_changed
# 0                  1            7              0              1
# 1                 44           19              1             23
# 2                  0            2              0              0
# 3                 10            2              1              4
# 4                  1            0              0              1
# 5                155            4             43              8
# 6                  1            1              0              1
# 7                  0            1              0              0
# 8                 90            0             84              1
# 9                 50            4              4              7
# 10                11            0              1              6
# 11                 1            1              0              1
# 12                 1            0              0              1
# 13                 2           20              1              1
# 14                 1            0              0              1
# 15                 2            0              0              1
# 16                 7            2              0              4
# 17                41            4              1             14
# 18                71            0             58              0
# 19                 2            0              0              2
# 20                 0            2              0              0
# 21                 5            0              0              5
# 22                 0            1              0              0
# 23                 0            1              0              0
# 24               107            9              4             12
# 25                 1            0              0              1
# 26                 1            0              0              1
# 27                 2            0              0              2
# 28                 2           13              0              2
# 29                16            0              2              2
# ...              ...          ...            ...            ...
# 63602              2            2              0              1
# 63603              1            3              0              1
# 63604              2            4              0              2
# 63605              3            0              0              1
# 63606            660            1              1              1
# 63607             21            2              1              6
# 63608              0            6              0              0
# 63609            108            0              1              0
# 63610             20            5              2              4
# 63611              4            5              2              2
# 63612             10            7              0              7
# 63613              0            1              0              0
# 63614              1            0              0              1
# 63615              5            0              0              1
# 63616              9            0              2              4
# 63617              0            2              0              0
# 63618              3            1              1              2
# 63619              0            1              0              0
# 63620              3            3              0              3
# 63621              1            1              0              1
# 63622              1            0              0              1
# 63623              1            0              0              1
# 63624              4            2              0              4
# 63625              1            0              0              1
# 63626              2            1              0              2
# 63627             94            0              1              0
# 63628              0            2              0              0
# 63629              4            5              2              2
# 63630              1            1              0              1
# 63631              2            0              1              1
#
# [63632 rows x 13 columns]

# %%
file_changes.toPandas()
# Out:
#        change_type                                               path  \
# 0           Modify  dbms/src/Interpreters/JoinToSubqueryTransformV...
# 1           Modify  dbms/src/Interpreters/TranslateQualifiedNamesV...
# 2           Modify                     dbms/src/Parsers/ASTAsterisk.h
# 3           Modify            dbms/src/Parsers/ASTQualifiedAsterisk.h
# 4           Modify  dbms/src/Storages/MergeTree/MergeTreeBloomFilt...
# 5           Modify  dbms/src/Storages/MergeTree/MergeTreeBloomFilt...
# 6           Modify              dbms/src/Interpreters/BloomFilter.cpp
# 7           Modify                dbms/src/Interpreters/BloomFilter.h
# 8           Modify  dbms/src/Storages/MergeTree/MergeTreeBloomFilt...
# 9           Modify  dbms/src/Storages/MergeTree/MergeTreeBloomFilt...
# 10          Modify      dbms/src/Storages/MergeTree/MergeTreeData.cpp
# 11          Modify   dbms/src/Storages/MergeTree/MergeTreeIndices.cpp
# 12          Modify     dbms/src/Storages/MergeTree/MergeTreeIndices.h
# 13          Modify  dbms/src/Storages/MergeTree/MergeTreeMinMaxInd...
# 14          Modify  dbms/src/Storages/MergeTree/MergeTreeSetSkippi...
# 15          Modify  dbms/src/Storages/MergeTree/MergeTreeBloomFilt...
# 16          Modify  dbms/src/Interpreters/JoinToSubqueryTransformV...
# 17          Modify                                    CHANGELOG_RU.md
# 18          Modify                                    CHANGELOG_RU.md
# 19          Modify                                    CHANGELOG_RU.md
# 20          Modify                                    CHANGELOG_RU.md
# 21          Modify                                    CHANGELOG_RU.md
# 22          Modify  dbms/tests/queries/0_stateless/00900_parquet_c...
# 23          Modify  dbms/tests/queries/0_stateless/data_parquet/al...
# 24          Modify  dbms/tests/queries/0_stateless/data_parquet/al...
# 25          Modify  dbms/tests/queries/0_stateless/data_parquet/al...
# 26          Modify  dbms/tests/queries/0_stateless/data_parquet/by...
# 27          Modify  dbms/tests/queries/0_stateless/data_parquet/da...
# 28          Modify  dbms/tests/queries/0_stateless/data_parquet/fi...
# 29          Modify  dbms/tests/queries/0_stateless/data_parquet/fi...
# ...            ...                                                ...
# 268744      Modify  tests/queries/0_stateless/02493_max_streams_fo...
# 268745      Rename   tests/ci/runner_token_rotation_lambda/Dockerfile
# 268746      Rename       tests/ci/runner_token_rotation_lambda/app.py
# 268747      Rename  tests/ci/runner_token_rotation_lambda/requirem...
# 268748      Modify       tests/ci/runner_token_rotation_lambda/app.py
# 268749      Delete   tests/ci/runner_token_rotation_lambda/Dockerfile
# 268750         Add  tests/ci/runner_token_rotation_lambda/build_an...
# 268751      Rename        tests/ci/terminate_runner_lambda/Dockerfile
# 268752      Rename            tests/ci/terminate_runner_lambda/app.py
# 268753      Rename  tests/ci/terminate_runner_lambda/requirements.txt
# 268754      Modify            tests/ci/terminate_runner_lambda/app.py
# 268755      Delete        tests/ci/terminate_runner_lambda/Dockerfile
# 268756         Add  tests/ci/terminate_runner_lambda/build_and_dep...
# 268757      Modify               src/Interpreters/DatabaseCatalog.cpp
# 268758      Modify  tests/integration/test_broken_detached_part_cl...
# 268759      Modify   tests/ci/cancel_and_rerun_workflow_lambda/app.py
# 268760      Modify  src/AggregateFunctions/AggregateFunctionMinMax...
# 268761         Add  tests/queries/0_stateless/02431_single_value_o...
# 268762         Add  tests/queries/0_stateless/02431_single_value_o...
# 268763      Modify   tests/ci/cancel_and_rerun_workflow_lambda/app.py
# 268764      Modify  tests/queries/0_stateless/02482_json_nested_ar...
# 268765      Modify  tests/integration/test_keeper_zookeeper_conver...
# 268766      Modify        src/Storages/StorageReplicatedMergeTree.cpp
# 268767      Modify        src/Common/tests/gtest_config_processor.cpp
# 268768      Modify                          docker/test/stress/run.sh
# 268769      Modify                 src/Interpreters/TreeOptimizer.cpp
# 268770      Modify                   src/Interpreters/TreeOptimizer.h
# 268771      Modify                  src/Interpreters/TreeRewriter.cpp
# 268772         Add  tests/queries/0_stateless/02494_optimize_group...
# 268773         Add  tests/queries/0_stateless/02494_optimize_group...
#
#                                             old_path file_extension  \
# 0                                               None              h
# 1                                               None            cpp
# 2                                               None              h
# 3                                               None              h
# 4                                               None            cpp
# 5                                               None              h
# 6                                               None            cpp
# 7                                               None              h
# 8                                               None            cpp
# 9                                               None              h
# 10                                              None            cpp
# 11                                              None            cpp
# 12                                              None              h
# 13                                              None            cpp
# 14                                              None            cpp
# 15                                              None            cpp
# 16                                              None            cpp
# 17                                              None             md
# 18                                              None             md
# 19                                              None             md
# 20                                              None             md
# 21                                              None             md
# 22                                              None             pl
# 23                                              None        columns
# 24                                              None        columns
# 25                                              None        columns
# 26                                              None        columns
# 27                                              None        columns
# 28                                              None        columns
# 29                                              None        columns
# ...                                              ...            ...
# 268744                                          None            sql
# 268745              tests/ci/token_lambda/Dockerfile           None
# 268746                  tests/ci/token_lambda/app.py             py
# 268747        tests/ci/token_lambda/requirements.txt            txt
# 268748                                          None             py
# 268749                                          None           None
# 268750                                          None             sh
# 268751        tests/ci/termination_lambda/Dockerfile           None
# 268752            tests/ci/termination_lambda/app.py             py
# 268753  tests/ci/termination_lambda/requirements.txt            txt
# 268754                                          None             py
# 268755                                          None           None
# 268756                                          None             sh
# 268757                                          None            cpp
# 268758                                          None             py
# 268759                                          None             py
# 268760                                          None              h
# 268761                                          None      reference
# 268762                                          None            sql
# 268763                                          None             py
# 268764                                          None             sh
# 268765                                          None             py
# 268766                                          None            cpp
# 268767                                          None            cpp
# 268768                                          None             sh
# 268769                                          None            cpp
# 268770                                          None              h
# 268771                                          None            cpp
# 268772                                          None      reference
# 268773                                          None            sql
#
#         lines_added  lines_deleted  hunks_added  hunks_removed  hunks_changed  \
# 0                 1              1            0              0              1
# 1                38             11            4              0              3
# 2                 8              0            2              0              0
# 3                 8              0            2              0              0
# 4               103              0            2              0              0
# 5                 4              2            0              0              2
# 6                 5              0            1              0              0
# 7                 1              0            1              0              0
# 8                21             10            3              1              6
# 9                 2              1            1              0              1
# 10                1              0            1              0              0
# 11               13              1            5              0              1
# 12                2              0            2              0              0
# 13                1              0            1              0              0
# 14                1              0            1              0              0
# 18                         0                     0
# 19                         0                     1
# 20                         0                     1
# 21                         0                     1
# 22                         0                    26
# 23                         0                    26
# 24                         0                    26
# 25                         0                    26
# 26                         0                    26
# 27                         0                    26
# 28                         0                    26
# 29                         0                    26
# ...                      ...                   ...
# 268744                     0                     5
# 268745                     0                     0
# 268746                     0                     0
# 268747                     0                     0
# 268748                     3                     0
# 268749                     1                     0
# 268750                     1                     0
# 268751                     0                     0
# 268752                     0                     0
# 268753                     0                     0
# 268754                     2                     0
# 268755                     1                     0
# 268756                     1                     0
# 268757                     0                     0
# 268758                     0                     0
# 268759                     0                     4
# 268760                     4                     2
# 268761                     4                     2
# 268762                     4                     2
# 268763                     0                     1
# 268764                     0                     1
# 268765                     0                     2
# 268766                     0                     2
# 268767                     0                     1
# 268768                     0                     0
# 268769                     1                     1
# 268770                     1                     1
# 268771                     1                     1
# 268772                     1                     1
# 268773                     1                     1
#
# [268774 rows x 19 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
line_changes.limit(100).toPandas()
# Out:
#     sign  line_number_old  line_number_new  hunk_num  \
# 0     -1               27               27         1
# 1      1               28               27         1
# 2      1                0               17         1
# 3     -1              270              270         1
# 4      1              271              270         1
# 5     -1               23               33         4
# 6      1               24               33         4
# 7     -1               53               65         5
# 8     -1               54               65         5
# 9     -1               55               65         5
# 10    -1               56               65         5
# 11    -1               57               65         5
# 12    -1               58               65         5
# 13    -1               59               65         5
# 14    -1               60               65         5
# 15    -1               61               65         5
# 16    -1               62               65         5
# 17    -1               63               65         5
# 18    -1               64               65         5
# 19    -1               65               65         5
# 20    -1               66               65         5
# 21    -1               67               65         5
# 22    -1               68               65         5
# 23    -1               69               65         5
# 24    -1               70               65         5
# 25    -1               85               80         6
# 26     1               86               80         6
# 27    -1               96               91         7
# 28    -1               97               91         7
# 29    -1               98               91         7
# ..   ...              ...              ...       ...
# 70     1               59               56         7
# 71    -1               67               66         9
# 72     1               68               66         9
# 73    -1               12               12         1
# 74     1               13               12         1
# 75    -1               18               17         2
# 76    -1               22               21         3
# 77    -1               23               21         3
# 78     1               24               21         3
# 79    -1               27               24         4
# 80    -1               29               26         5
# 81     1               30               26         5
# 82    -1               14               14         1
# 83    -1               15               14         1
# 84     1               16               14         1
# 85    -1               34               33         2
# 86    -1               35               33         2
# 87     1               36               33         2
# 88    -1               42               40         3
# 89    -1               43               40         3
# 90     1               44               40         3
# 91    -1               53               50         4
# 92    -1               54               50         4
# 93     1               55               50         4
# 94    -1               79               74         5
# 95    -1               80               74         5
# 96    -1               81               74         5
# 97    -1               82               74         5
# 98    -1               83               74         5
# 99    -1               84               74         5
#
#     hunk_start_line_number_old  hunk_start_line_number_new  hunk_lines_added  \
# 0                           27                          27                 1
# 1                           27                          27                 1
# 2                            0                           1                30
# 3                          270                         270                 1
# 4                          270                         270                 1
# 5                           23                          33                 4
# 6                           23                          33                 4
# 7                           53                          65                 0
# 8                           53                          65                 0
# 9                           53                          65                 0
# 10                          53                          65                 0
# 11                          53                          65                 0
# 12                          53                          65                 0
# 13                          53                          65                 0
# 14                          53                          65                 0
# 15                          53                          65                 0
# 16                          53                          65                 0
# 17                          53                          65                 0
# 18                          53                          65                 0
# 19                          53                          65                 0
# 20                          53                          65                 0
# 21                          53                          65                 0
# 22                          53                          65                 0
# 23                          53                          65                 0
# 24                          53                          65                 0
# 25                          85                          80                 1
# 26                          85                          80                 1
# 27                          96                          91                 1
# 28                          96                          91                 1
# 29                          96                          91                 1
# ..                         ...                         ...               ...
# 70                          57                          55                 2
# 71                          67                          66                 3
# 72                          67                          66                 3
# 73                          12                          12                 1
# 74                          12                          12                 1
# 75                          18                          17                 0
# 76                          22                          21                 1
# 77                          22                          21                 1
# 78                          22                          21                 1
# 79                          27                          24                 0
# 80                          29                          26                 2
# 81                          29                          26                 2
# 82                          14                          14                 1
# 83                          14                          14                 1
# 84                          14                          14                 1
# 85                          34                          33                 1
# 86                          34                          33                 1
# 87                          34                          33                 1
# 88                          42                          40                 1
# 89                          42                          40                 1
# 90                          42                          40                 1
# 91                          53                          50                 1
# 92                          53                          50                 1
# 93                          53                          50                 1
# 94                          79                          74                 0
# 95                          79                          74                 0
# 96                          79                          74                 0
# 97                          79                          74                 0
# 98                          79                          74                 0
# 99                          79                          74                 0
#
#     hunk_lines_deleted                                       hunk_context  \
# 0                    1  $CLICKHOUSE_CLIENT --query="SELECT * FROM set_...
# 1                    1  $CLICKHOUSE_CLIENT --query="SELECT * FROM set_...
# 2                    0                                               None
# 3                    1                                               None
# 4                    1                                               None
# 5                    1  String NATSConnectionManager::connectionInfoFo...
# 6                    1  String NATSConnectionManager::connectionInfoFo...
# 7                   18            bool NATSConnectionManager::reconnect()
# 8                   18            bool NATSConnectionManager::reconnect()
# 9                   18            bool NATSConnectionManager::reconnect()
# 10                  18            bool NATSConnectionManager::reconnect()
# 11                  18            bool NATSConnectionManager::reconnect()
# 12                  18            bool NATSConnectionManager::reconnect()
# 13                  18            bool NATSConnectionManager::reconnect()
# 14                  18            bool NATSConnectionManager::reconnect()
# 15                  18            bool NATSConnectionManager::reconnect()
# 16                  18            bool NATSConnectionManager::reconnect()
# 17                  18            bool NATSConnectionManager::reconnect()
# 18                  18            bool NATSConnectionManager::reconnect()
# 19                  18            bool NATSConnectionManager::reconnect()
# 20                  18            bool NATSConnectionManager::reconnect()
# 21                  18            bool NATSConnectionManager::reconnect()
# 22                  18            bool NATSConnectionManager::reconnect()
# 23                  18            bool NATSConnectionManager::reconnect()
# 24                  18            bool NATSConnectionManager::reconnect()
# 25                   1  bool NATSConnectionManager::isConnectedImpl() ...
# 26                   1  bool NATSConnectionManager::isConnectedImpl() ...
# 27                   6          void NATSConnectionManager::connectImpl()
# 28                   6          void NATSConnectionManager::connectImpl()
# 29                   6          void NATSConnectionManager::connectImpl()
# ..                 ...                                                ...
# 70                   2                                           private:
# 71                   1                                           private:
# 72                   1                                           private:
# 73                   1                                       namespace DB
# 74                   1                                       namespace DB
# 75                   1                                       namespace DB
# 76                   2                                       namespace DB
# 77                   2                                       namespace DB
# 78                   2                                       namespace DB
# 79                   1                                       namespace DB
# 80                   1                                       namespace DB
# 81                   1                                       namespace DB
# 82                   2  static std::pair<Block, Block> getHeaders(cons...
# 83                   2  static std::pair<Block, Block> getHeaders(cons...
# 84                   2  static std::pair<Block, Block> getHeaders(cons...
# 85                   2                            NATSSource::NATSSource(
# 86                   2                            NATSSource::NATSSource(
# 87                   2                            NATSSource::NATSSource(
# 88                   2                            NATSSource::NATSSource(
# 89                   2                            NATSSource::NATSSource(
# 90                   2                            NATSSource::NATSSource(
# 91                   2                            NATSSource::NATSSource(
# 92                   2                            NATSSource::NATSSource(
# 93                   2                            NATSSource::NATSSource(
# 94                  21                          NATSSource::~NATSSource()
# 95                  21                          NATSSource::~NATSSource()
# 96                  21                          NATSSource::~NATSSource()
# 97                  21                          NATSSource::~NATSSource()
# 98                  21                          NATSSource::~NATSSource()
# 99                  21                          NATSSource::~NATSSource()
#
#                                                  line  indent line_type  \
# 0    $CLICKHOUSE_CLIENT --query="DROP TABLE set_idx;"   255.0      Code
# 1    $CLICKHOUSE_CLIENT --query="DROP TABLE set_idx;"   255.0      Code
# 2   \t255\tPunct\t\t\t0000-00-00 00:00:00\tAdd\tte...     NaN      None
# 3         url = https://github.com/nats-io/nats.c.git   255.0      Code
# 4       url = https://github.com/tchepavel/nats.c.git   255.0      Code
# 5   return configuration.host + \':\' + toString(c...   255.0      Code
# 6                   if (!configuration.url.empty()) {   255.0      Code
# 7   SubscriptionPtr NATSConnectionManager::createS...   255.0      Code
# 8                                                   {   255.0     Punct
# 9                        std::lock_guard lock(mutex);   255.0      Code
# 10                             natsSubscription * ns;   255.0      Code
# 11  status = natsConnection_Subscribe(&ns, connect...   255.0      Code
# 12                             if (status == NATS_OK)   255.0      Code
# 13  status = natsSubscription_SetPendingLimits(ns,...   255.0      Code
# 14                             if (status == NATS_OK)   255.0      Code
# 15                                                  {   255.0     Punct
# 16  LOG_DEBUG(log, "Subscribed to subject {}", sub...   255.0      Code
# 17  return SubscriptionPtr(ns, &natsSubscription_D...   255.0      Code
# 18                                                  }   255.0     Punct
# 19                                               else   255.0      Code
# 20                                                  {   255.0     Punct
# 21  return SubscriptionPtr(nullptr, &natsSubscript...   255.0      Code
# 22                                                  }   255.0     Punct
# 23                                                  }   255.0     Punct
# 24                                               None   255.0     Empty
# 25  return event_handler.connectionRunning() && !n...   255.0      Code
# 26  return event_handler.connectionRunning() && co...   255.0      Code
# 27                               std::string address;   255.0      Code
# 28       if (configuration.connection_string.empty())   255.0      Code
# 29                                                  {   255.0     Punct
# ..                                                ...     ...       ...
# 70  static void reconnectedCallback(natsConnection...   255.0      Code
# 71                                 natsStatus status;   255.0      Code
# 72  // true if at any point was a successful conne...   255.0   Comment
# 73  M(String, nats_host_port, "", "A host-port to ...   255.0      Code
# 74  M(String, nats_url, "", "A host-port to connec...   255.0      Code
# 75  M(Bool, nats_persistent, false, "For insert qu...   255.0      Code
# 76  M(String, nats_password, "", "NATS password", ...   255.0      Code
# 77  M(String, nats_address, "", "Address for conne...   255.0      Code
# 78  M(String, nats_server_list, "", "Server list f...   255.0      Code
# 79  M(Bool, nats_queue_consume, false, "Use user-d...   255.0      Code
# 80  M(Bool, nats_commit_on_select, false, "Commit ...   255.0      Code
# 81  M(String, nats_password, "", "NATS password", ...   255.0      Code
# 82  auto virtual_header = storage_snapshot->getSam...   255.0      Code
# 83                       {"_subject", "_timestamp"});   255.0      Code
# 84  auto virtual_header = storage_snapshot->getSam...   255.0      Code
# 85                            size_t max_block_size_,   255.0      Code
# 86                               bool ack_in_suffix_)   255.0      Code
# 87                            size_t max_block_size_)   255.0      Code
# 88                                   max_block_size_,   255.0      Code
# 89                                    ack_in_suffix_)   255.0      Code
# 90                                   max_block_size_)   255.0      Code
# 91                            size_t max_block_size_,   255.0      Code
# 92                           bool /*ack_in_suffix_*/)   255.0      Code
# 93                            size_t max_block_size_)   255.0      Code
# 94                                               None   255.0     Empty
# 95             //bool NATSSource::needChannelUpdate()   255.0   Comment
# 96                                                //{   255.0   Comment
# 97                                 //    if (!buffer)   255.0   Comment
# 98                            //        return false;   255.0   Comment
# 99                                                 //   255.0   Comment
#
#                             prev_commit_hash           prev_time  \
# 0   f1cc83ca9e9d76803480f6d2d158c5cffe98086d 2019-04-16 15:13:13
# 1   f1cc83ca9e9d76803480f6d2d158c5cffe98086d 2019-04-16 15:13:13
# 2                                       None                 NaT
# 3   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 4   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 5   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 6   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 7   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 8   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 9   944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 10  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 11  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 12  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 13  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 14  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 15  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 16  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 17  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 18  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 19  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 20  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 21  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 22  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 23  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 24  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 25  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 26  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 27  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 28  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 29  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# ..                                       ...                 ...
# 70  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 71  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 72  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 73  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 74  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 75  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 76  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 77  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 78  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 79  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 80  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 81  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 82  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 83  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 84  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 85  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 86  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 87  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 88  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 89  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 90  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 91  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 92  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 93  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 94  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 95  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 96  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 97  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 98  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
# 99  944a729fc531f5bce1569c414fcc5546914d26bc 2022-05-12 11:58:49
#
#    file_change_type                                               path  \
# 0            Modify  tests/queries/0_stateless/00907_set_index_max_...
# 1            Modify  tests/queries/0_stateless/00907_set_index_max_...
# 2              None                                               None
# 3            Modify                                        .gitmodules
# 4            Modify                                        .gitmodules
# 5            Modify               src/Storages/NATS/NATSConnection.cpp
# 6            Modify               src/Storages/NATS/NATSConnection.cpp
# 7            Modify               src/Storages/NATS/NATSConnection.cpp
# 8            Modify               src/Storages/NATS/NATSConnection.cpp
# 9            Modify               src/Storages/NATS/NATSConnection.cpp
# 10           Modify               src/Storages/NATS/NATSConnection.cpp
# 11           Modify               src/Storages/NATS/NATSConnection.cpp
# 12           Modify               src/Storages/NATS/NATSConnection.cpp
# 13           Modify               src/Storages/NATS/NATSConnection.cpp
# 14           Modify               src/Storages/NATS/NATSConnection.cpp
# 15           Modify               src/Storages/NATS/NATSConnection.cpp
# 16           Modify               src/Storages/NATS/NATSConnection.cpp
# 17           Modify               src/Storages/NATS/NATSConnection.cpp
# 18           Modify               src/Storages/NATS/NATSConnection.cpp
# 19           Modify               src/Storages/NATS/NATSConnection.cpp
# 20           Modify               src/Storages/NATS/NATSConnection.cpp
# 21           Modify               src/Storages/NATS/NATSConnection.cpp
# 22           Modify               src/Storages/NATS/NATSConnection.cpp
# 23           Modify               src/Storages/NATS/NATSConnection.cpp
# 24           Modify               src/Storages/NATS/NATSConnection.cpp
# 25           Modify               src/Storages/NATS/NATSConnection.cpp
# 26           Modify               src/Storages/NATS/NATSConnection.cpp
# 27           Modify               src/Storages/NATS/NATSConnection.cpp
# 28           Modify               src/Storages/NATS/NATSConnection.cpp
# 29           Modify               src/Storages/NATS/NATSConnection.cpp
# ..              ...                                                ...
# 70           Modify                 src/Storages/NATS/NATSConnection.h
# 71           Modify                 src/Storages/NATS/NATSConnection.h
# 72           Modify                 src/Storages/NATS/NATSConnection.h
# 73           Modify                   src/Storages/NATS/NATSSettings.h
# 74           Modify                   src/Storages/NATS/NATSSettings.h
# 75           Modify                   src/Storages/NATS/NATSSettings.h
# 76           Modify                   src/Storages/NATS/NATSSettings.h
# 77           Modify                   src/Storages/NATS/NATSSettings.h
# 78           Modify                   src/Storages/NATS/NATSSettings.h
# 79           Modify                   src/Storages/NATS/NATSSettings.h
# 80           Modify                   src/Storages/NATS/NATSSettings.h
# 81           Modify                   src/Storages/NATS/NATSSettings.h
# 82           Modify                   src/Storages/NATS/NATSSource.cpp
# 83           Modify                   src/Storages/NATS/NATSSource.cpp
# 84           Modify                   src/Storages/NATS/NATSSource.cpp
# 85           Modify                   src/Storages/NATS/NATSSource.cpp
# 86           Modify                   src/Storages/NATS/NATSSource.cpp
# 87           Modify                   src/Storages/NATS/NATSSource.cpp
# 88           Modify                   src/Storages/NATS/NATSSource.cpp
# 89           Modify                   src/Storages/NATS/NATSSource.cpp
# 90           Modify                   src/Storages/NATS/NATSSource.cpp
# 91           Modify                   src/Storages/NATS/NATSSource.cpp
# 92           Modify                   src/Storages/NATS/NATSSource.cpp
# 93           Modify                   src/Storages/NATS/NATSSource.cpp
# 94           Modify                   src/Storages/NATS/NATSSource.cpp
# 95           Modify                   src/Storages/NATS/NATSSource.cpp
# 96           Modify                   src/Storages/NATS/NATSSource.cpp
# 97           Modify                   src/Storages/NATS/NATSSource.cpp
# 98           Modify                   src/Storages/NATS/NATSSource.cpp
# 99           Modify                   src/Storages/NATS/NATSSource.cpp
#
#    old_path file_extension  file_lines_added  file_lines_deleted  \
# 0      None             sh               1.0                 1.0
# 1      None             sh               1.0                 1.0
# 2      None           None               NaN                 NaN
# 3      None           None               1.0                 1.0
# 4      None           None               1.0                 1.0
# 5      None            cpp              36.0                38.0
# 6      None            cpp              36.0                38.0
# 7      None            cpp              36.0                38.0
# 8      None            cpp              36.0                38.0
# 9      None            cpp              36.0                38.0
# 10     None            cpp              36.0                38.0
# 11     None            cpp              36.0                38.0
# 12     None            cpp              36.0                38.0
# 13     None            cpp              36.0                38.0
# 14     None            cpp              36.0                38.0
# 15     None            cpp              36.0                38.0
# 16     None            cpp              36.0                38.0
# 17     None            cpp              36.0                38.0
# 18     None            cpp              36.0                38.0
# 19     None            cpp              36.0                38.0
# 20     None            cpp              36.0                38.0
# 86               0.0                 5.0                 4.0
# 87               0.0                 5.0                 4.0
# 88               0.0                 5.0                 4.0
# 89               0.0                 5.0                 4.0
# 90               0.0                 5.0                 4.0
# 91               0.0                 5.0                 4.0
# 92               0.0                 5.0                 4.0
# 93               0.0                 5.0                 4.0
# 94               0.0                 5.0                 4.0
# 95               0.0                 5.0                 4.0
# 96               0.0                 5.0                 4.0
# 97               0.0                 5.0                 4.0
# 98               0.0                 5.0                 4.0
# 99               0.0                 5.0                 4.0
#
#                                  commit_hash  commit_hunks_changed
# 0   6adbd516cc16b5476d5e474a9000cbb6e870489b                   1.0
# 1   6adbd516cc16b5476d5e474a9000cbb6e870489b                   1.0
# 2                                       None                   NaN
# 3   30ff0de33e2353af3057af62ade67b50ce290326                   1.0
# 4   30ff0de33e2353af3057af62ade67b50ce290326                   1.0
# 5   f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 6   f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 7   f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 8   f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 9   f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 10  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 11  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 12  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 13  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 14  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 15  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 16  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 17  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 18  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 19  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 20  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 21  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 22  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 23  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 24  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 25  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 26  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 27  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 28  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 29  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# ..                                       ...                   ...
# 70  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 71  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 72  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 73  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 74  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 75  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 76  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 77  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 78  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 79  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 80  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 81  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 82  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 83  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 84  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 85  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 86  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 87  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 88  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 89  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 90  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 91  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 92  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 93  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 94  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 95  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 96  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 97  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 98  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
# 99  f53ec6a3a5ba605d58a09912226ac9f889af7d83                  57.0
#
# [100 rows x 25 columns]

# %% [markdown]
# ### Посмотреть актиновность Миловидова
#
# Испольвать сальтирование; Проблема перекоса данных data skew. При join по такому ключу спарк не может равномерно распределить нагрузку по воркерам - и один из них получает больше нагрузки чем другие

# %%
# 1. first use groupBy key
line_changes.groupBy(col("commit_hash").isNull()).count().show()
# Out:
# +---------------------+-------+
# |(commit_hash IS NULL)|  count|
# +---------------------+-------+
# |                 true|   1173|
# |                false|3706031|
# +---------------------+-------+

# %%
dropna_line_changes = line_changes.filter(line_changes.commit_hash.isNotNull())

# %%
res = (dropna_line_changes
    .join(file_changes, dropna_line_changes.commit_hash == file_changes.commit_hash, "left")
    .join(commits, dropna_line_changes.commit_hash == commits.hash, "left")
    .select(commits.author, dropna_line_changes.file_lines_added, dropna_line_changes.file_lines_deleted))

# %%
res.groupBy(col("author")).count().orderBy("count", ascending=False).show(20)
# Out:
# +-------------------+--------+
# |             author|   count|
# +-------------------+--------+
# |   Alexey Milovidov|77693987|
# |Mikhail f. Shiryaev|41646478|
# |              s-kat|27258099|
# |            CurtizJ|20364564|
# |            Mikhail|17428481|
# |               Ivan|14114840|
# |      Alexey Boykov|10692510|
# |            proller| 8131804|
# |   Nikolai Kochetov| 5264636|
# |     Ivan Lezhankin| 3736818|
# |             MyroTk| 3243188|
# |              myrrc| 3104617|
# |        Maksim Kita| 2917352|
# |     Vitaly Baranov| 2494085|
# |   alexey-milovidov| 2233864|
# |       kreuzerkrieg| 1962173|
# |Nikolay Degterinsky| 1859890|
# |        Anton Popov| 1784461|
# |       Azat Khuzhin| 1748650|
# |             Li Yin| 1578577|
# +-------------------+--------+
# only showing top 20 rows

# %% [markdown]
# ### Найти самые часто исправляемые файлы
# и собрать массив кто их правил

# %%
most_modified_df = (dropna_line_changes
    .join(file_changes, dropna_line_changes.commit_hash == file_changes.commit_hash, "left")
    .join(commits, dropna_line_changes.commit_hash == commits.hash, "left")
    .select(file_changes.path, commits.author))

# %%
most_modified_df.groupBy(col('path')).count().orderBy("count", ascending=False).show(20)
# Out:
# +--------------------+------+
# |                path| count|
# +--------------------+------+
# |src/Functions/CMa...|247317|
# |  src/CMakeLists.txt|225001|
# |         .gitmodules|211975|
# |      CMakeLists.txt|209441|
# |programs/server/S...|206424|
# |src/Common/Freque...|187237|
# |src/Functions/Fun...|183904|
# |dbms/src/Storages...|182694|
# |src/Functions/Fun...|182087|
# |dbms/src/Storages...|179309|
# |cmake/find/cld2.c...|177957|
# |programs/server/e...|177955|
# |programs/server/c...|177955|
# |src/Storages/Stor...|168982|
# |dbms/src/Interpre...|167363|
# |src/Storages/Merg...|166921|
# | src/Core/Settings.h|165679|
# |src/Functions/reg...|154836|
# |dbms/src/Interpre...|153122|
# |src/Interpreters/...|152267|
# +--------------------+------+
# only showing top 20 rows

# %%
authors_by_path = (
    most_modified_df
    .groupBy("path")
    .agg(
        collect_set("author").alias("authors"),
        count("*").alias("modification_count")
    )
    .orderBy("modification_count", ascending=False)
)

authors_by_path.show(20)
# Out:
# +--------------------+--------------------+------------------+
# |                path|             authors|modification_count|
# +--------------------+--------------------+------------------+
# |src/Functions/CMa...|[Andr0901, Boloni...|            247317|
# |  src/CMakeLists.txt|[msaf1980, Mikhai...|            225001|
# |         .gitmodules|[Ivan Blinkov, Al...|            211975|
# |      CMakeLists.txt|[Ivan Blinkov, ch...|            209441|
# |programs/server/S...|[Timur Magomedov,...|            206424|
# |src/Common/Freque...|[Maksim Kita, s-k...|            187237|
# |src/Functions/Fun...|[Li Yin, Azat Khu...|            183904|
# |dbms/src/Storages...|[chertus, Vitaliy...|            182694|
# |src/Functions/Fun...|[Li Yin, Maksim K...|            182087|
# |dbms/src/Storages...|[Akazz, maiha, Vi...|            179309|
# |cmake/find/cld2.c...|[s-kat, Nikolay D...|            177957|
# |programs/server/e...|[s-kat, Nikolay D...|            177955|
# |programs/server/c...|[s-kat, Nikolay D...|            177955|
# |src/Storages/Stor...|[Vasily Nemkov, J...|            168982|
# |dbms/src/Interpre...|[maiha, chertus, ...|            167363|
# |src/Storages/Merg...|[Alexey Milovidov...|            166921|
# | src/Core/Settings.h|[Vxider, Sergei T...|            165679|
# |src/Functions/reg...|[Vasily Nemkov, M...|            154836|
# |dbms/src/Interpre...|[chertus, Alexey ...|            153122|
# |src/Interpreters/...|[Vasily Nemkov, n...|            152267|
# +--------------------+--------------------+------------------+
# only showing top 20 rows

# %%
# authors_by_path = (most_modified_df.groupBy("path")
#     .agg(collect_set("author").alias("authors_list"), count("*").alias("count"))
#     .orderBy("count", ascending=False)
# )

# authors_by_path.show(20)

# %% [markdown]
# ### Построить воронки коммитеров по годам
# найти тех отвалился со временем
# создать витрину в которой будет написано
